# %%
import pymongo
import dns # required for connecting with SRV
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb+srv://m220student:m220password@mflix.pzqmc.mongodb.net/admin?retryWrites=true&w=majority")
client.test
# Out:
# Database(MongoClient(host=['mflix-shard-00-01.pzqmc.mongodb.net:27017', 'mflix-shard-00-00.pzqmc.mongodb.net:27017', 'mflix-shard-00-02.pzqmc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-140cqu-shard-0', ssl=True), 'test')

# %%
df = pd.read_csv("bbc_scraped_articles.csv")
df.head(1)
# Out:
#                                            head_line  \
# 0  'You are not alone' says Queen in Christmas sp...
#
#                                     url  \
# 0  https://www.bbc.com/news/uk-55447011
#
#                                              summary  \
# 0  She says that while all many people want is "a...
#
#                        date                                               text
# 0  2020-12-25T15:50:19.000Z  The Queen has used her Christmas Day message t...

# %%
a = df['head_line']
type(a)
# Out:
# pandas.core.series.Series

# %%
db = client.news
for row in df.iterrows():
    
    article={
        'head_line':row[1]['head_line'], 'url':row[1]['url'], 'summary':row[1]['summary'],
         'date':row[1]['date'], 'article_text':row[1]['text']
                                                      }
    db.bbc_articles.insert_one(article)
    print("article inserted")
    
print("df inserted")
# Out:
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# article inserted
# df inserted

# %%
from pymongo import TEXT
db.bbc_articles.create_index([('article_text', TEXT)], default_language='english')
# Out:
# 'article_text_text'

# %%
find = db.bbc_articles.find({"$text": {"$search": "Queen"}})

# %%
for article in find:
    print("{}\n".format(article['head_line']))
# Out:
# 'You are not alone' says Queen in Christmas speech
#
# Millions wake up to tighter Covid restrictions in UK
#
# Millions wake up to tighter Covid restrictions in UK

# %%
db.bbc_articles.find({"$text": {"$search": "virus"}}).count()
# Out:
# <ipython-input-24-f53e3c8c2614>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   db.bbc_articles.find({"$text": {"$search": "virus"}}).count()
# 1

# %%
from bson.json_util import dumps
print(dumps(find, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "5fe8aad32f773cd5f29a1fc9"
#     },
#     "head_line": "'You are not alone' says Queen in Christmas speech",
#     "url": "https://www.bbc.com/news/uk-55447011",
#     "summary": "She says that while all many people want is \"a squeeze of the hand\", there is \"hope in the new dawn\".",
#     "date": "2020-12-25T15:50:19.000Z",
# ...

# %%
from random import randint
db=client.business
#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=db.reviews.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# Created 1 of 500 as 5fe71efd3647334f20dbd552
# Created 2 of 500 as 5fe71efe3647334f20dbd553
# Created 3 of 500 as 5fe71efe3647334f20dbd554
# Created 4 of 500 as 5fe71eff3647334f20dbd555
# Created 5 of 500 as 5fe71eff3647334f20dbd556
# Created 6 of 500 as 5fe71eff3647334f20dbd557
# Created 7 of 500 as 5fe71eff3647334f20dbd558
# Created 8 of 500 as 5fe71eff3647334f20dbd559
# Created 9 of 500 as 5fe71eff3647334f20dbd55a
# Created 10 of 500 as 5fe71eff3647334f20dbd55b
# Created 11 of 500 as 5fe71eff3647334f20dbd55c
# Created 12 of 500 as 5fe71f003647334f20dbd55d
# Created 13 of 500 as 5fe71f003647334f20dbd55e
# Created 14 of 500 as 5fe71f003647334f20dbd55f
# Created 15 of 500 as 5fe71f003647334f20dbd560
# Created 16 of 500 as 5fe71f003647334f20dbd561
# Created 17 of 500 as 5fe71f003647334f20dbd562
# Created 18 of 500 as 5fe71f003647334f20dbd563
# Created 19 of 500 as 5fe71f013647334f20dbd564
# Created 20 of 500 as 5fe71f013647334f20dbd565
# Created 21 of 500 as 5fe71f013647334f20dbd566
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-6-a498fc98ed98> in <module>
#       1 mydict = { "name": "John", "address": "Highway 37" }
#       2
# ----> 3 x = mycol.insert_one(mydict)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# ...
